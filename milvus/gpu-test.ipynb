# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.4.1+cu124
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: C:\Users\PERSONA_AI\Documents\Prj\AUNIT RAG\RAG\rag\venv\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: accelerate, doclayout_yolo, marker-pdf, peft, sentence-transformers, surya-ocr, texify, thop, torchaudio, torchvision, ultralytics, ultralytics-thop
